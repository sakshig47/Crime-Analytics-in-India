# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Dell\\OneDrive\\Desktop\\Crime_Project\\Crime-Analytics-in-India\\crime_dataset_india (1).csv")

# %%
df
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0                  1   02-01-2020 0.00    01-01-2020 0.00    01-01-2020 1.11
# 1                  2  01-01-2020 19.00    01-01-2020 1.00    01-01-2020 6.26
# 2                  3   02-01-2020 5.00    01-01-2020 2.00   01-01-2020 14.30
# 3                  4   01-01-2020 5.00    01-01-2020 3.00   01-01-2020 14.46
# 4                  5  01-01-2020 21.00    01-01-2020 4.00   01-01-2020 16.51
# ...              ...               ...                ...                ...
# 40155          40156  01-08-2024 16.00   07-31-2024 03:00    31-07-2024 5.05
# 40156          40157  31-07-2024 14.00   07-31-2024 04:00    31-07-2024 4.14
# 40157          40158   02-08-2024 3.00   07-31-2024 05:00   31-07-2024 21.33
# 40158          40159  01-08-2024 19.00   07-31-2024 06:00   31-07-2024 11.05
# 40159          40160  31-07-2024 17.00   07-31-2024 07:00   31-07-2024 17.19
#
# ...

# %%
df.describe()
# Out:
#        Report Number    Crime Code   Victim Age  Police Deployed
# count   40160.000000  40160.000000  40160.00000     40160.000000
# mean    20080.500000    349.360259     44.49126        10.006250
# std     11593.337742    144.169205     20.22555         5.467951
# min         1.000000    100.000000     10.00000         1.000000
# 25%     10040.750000    225.000000     27.00000         5.000000
# 50%     20080.500000    349.000000     44.00000        10.000000
# 75%     30120.250000    474.000000     62.00000        15.000000
# max     40160.000000    599.000000     79.00000        19.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40160 entries, 0 to 40159
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Report Number       40160 non-null  int64
#  1   Date Reported       40160 non-null  str
#  2   Date of Occurrence  40160 non-null  str
#  3   Time of Occurrence  40160 non-null  str
#  4   City                40160 non-null  str
#  5   Crime Code          40160 non-null  int64
#  6   Crime Description   40160 non-null  str
#  7   Victim Age          40160 non-null  int64
#  8   Victim Gender       40160 non-null  str
#  9   Weapon Used         34370 non-null  str
#  10  Crime Domain        40160 non-null  str
#  11  Police Deployed     40160 non-null  int64
#  12  Case Closed         40160 non-null  str
#  13  Date Case Closed    40160 non-null  str
# dtypes: int64(4), str(10)
# memory usage: 8.0 MB

# %%
df.isnull().sum()
# Out:
# Report Number            0
# Date Reported            0
# Date of Occurrence       0
# Time of Occurrence       0
# City                     0
# Crime Code               0
# Crime Description        0
# Victim Age               0
# Victim Gender            0
# Weapon Used           5790
# Crime Domain             0
# Police Deployed          0
# Case Closed              0
# Date Case Closed         0
# dtype: int64

# %%
df.fillna("Unknown", inplace=True)
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0                  1   02-01-2020 0.00    01-01-2020 0.00    01-01-2020 1.11
# 1                  2  01-01-2020 19.00    01-01-2020 1.00    01-01-2020 6.26
# 2                  3   02-01-2020 5.00    01-01-2020 2.00   01-01-2020 14.30
# 3                  4   01-01-2020 5.00    01-01-2020 3.00   01-01-2020 14.46
# 4                  5  01-01-2020 21.00    01-01-2020 4.00   01-01-2020 16.51
# ...              ...               ...                ...                ...
# 40155          40156  01-08-2024 16.00   07-31-2024 03:00    31-07-2024 5.05
# 40156          40157  31-07-2024 14.00   07-31-2024 04:00    31-07-2024 4.14
# 40157          40158   02-08-2024 3.00   07-31-2024 05:00   31-07-2024 21.33
# 40158          40159  01-08-2024 19.00   07-31-2024 06:00   31-07-2024 11.05
# 40159          40160  31-07-2024 17.00   07-31-2024 07:00   31-07-2024 17.19
#
# ...

# %%
df.isnull().sum()
# Out:
# Report Number         0
# Date Reported         0
# Date of Occurrence    0
# Time of Occurrence    0
# City                  0
# Crime Code            0
# Crime Description     0
# Victim Age            0
# Victim Gender         0
# Weapon Used           0
# Crime Domain          0
# Police Deployed       0
# Case Closed           0
# Date Case Closed      0
# dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['report_number', 'date_reported', 'date_of_occurrence',
#        'time_of_occurrence', 'city', 'crime_code', 'crime_description',
#        'victim_age', 'victim_gender', 'weapon_used', 'crime_domain',
#        'police_deployed', 'case_closed', 'date_case_closed'],
#       dtype='str')

# %%
df
# Out:
#        report_number     date_reported date_of_occurrence time_of_occurrence  \
# 0                  1   02-01-2020 0.00    01-01-2020 0.00    01-01-2020 1.11
# 1                  2  01-01-2020 19.00    01-01-2020 1.00    01-01-2020 6.26
# 2                  3   02-01-2020 5.00    01-01-2020 2.00   01-01-2020 14.30
# 3                  4   01-01-2020 5.00    01-01-2020 3.00   01-01-2020 14.46
# 4                  5  01-01-2020 21.00    01-01-2020 4.00   01-01-2020 16.51
# ...              ...               ...                ...                ...
# 40155          40156  01-08-2024 16.00   07-31-2024 03:00    31-07-2024 5.05
# 40156          40157  31-07-2024 14.00   07-31-2024 04:00    31-07-2024 4.14
# 40157          40158   02-08-2024 3.00   07-31-2024 05:00   31-07-2024 21.33
# 40158          40159  01-08-2024 19.00   07-31-2024 06:00   31-07-2024 11.05
# 40159          40160  31-07-2024 17.00   07-31-2024 07:00   31-07-2024 17.19
#
# ...

# %%
print(df["date_of_occurrence"].head(20).tolist())
# Out:
# ['01-01-2020 0.00', '01-01-2020 1.00', '01-01-2020 2.00', '01-01-2020 3.00', '01-01-2020 4.00', '01-01-2020 5.00', '01-01-2020 6.00', '01-01-2020 7.00', '01-01-2020 8.00', '01-01-2020 9.00', '01-01-2020 10.00', '01-01-2020 11.00', '01-01-2020 12.00', '01-01-2020 13.00', '01-01-2020 14.00', '01-01-2020 15.00', '01-01-2020 16.00', '01-01-2020 17.00', '01-01-2020 18.00', '01-01-2020 19.00']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40160 entries, 0 to 40159
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   report_number       40160 non-null  int64
#  1   date_reported       40160 non-null  str
#  2   date_of_occurrence  40160 non-null  str
#  3   time_of_occurrence  40160 non-null  str
#  4   city                40160 non-null  str
#  5   crime_code          40160 non-null  int64
#  6   crime_description   40160 non-null  str
#  7   victim_age          40160 non-null  int64
#  8   victim_gender       40160 non-null  str
#  9   weapon_used         40160 non-null  str
#  10  crime_domain        40160 non-null  str
#  11  police_deployed     40160 non-null  int64
#  12  case_closed         40160 non-null  str
#  13  date_case_closed    40160 non-null  str
# dtypes: int64(4), str(10)
# memory usage: 8.0 MB

# %%
df["date_of_occurrence"] = df["date_of_occurrence"].str.split().str[0]

# %%
df["date_of_occurrence"] = pd.to_datetime(
    df["date_of_occurrence"],
    format="%m-%d-%Y"
)

# %%
df
# Out:
#        report_number     date_reported date_of_occurrence time_of_occurrence  \
# 0                  1   02-01-2020 0.00         2020-01-01    01-01-2020 1.11
# 1                  2  01-01-2020 19.00         2020-01-01    01-01-2020 6.26
# 2                  3   02-01-2020 5.00         2020-01-01   01-01-2020 14.30
# 3                  4   01-01-2020 5.00         2020-01-01   01-01-2020 14.46
# 4                  5  01-01-2020 21.00         2020-01-01   01-01-2020 16.51
# ...              ...               ...                ...                ...
# 40155          40156  01-08-2024 16.00         2024-07-31    31-07-2024 5.05
# 40156          40157  31-07-2024 14.00         2024-07-31    31-07-2024 4.14
# 40157          40158   02-08-2024 3.00         2024-07-31   31-07-2024 21.33
# 40158          40159  01-08-2024 19.00         2024-07-31   31-07-2024 11.05
# 40159          40160  31-07-2024 17.00         2024-07-31   31-07-2024 17.19
#
# ...

# %%
df["date_reported"] = df["date_reported"].str.split().str[0]

# %%
df["date_reported"].head(20)
# Out:
# 0     02-01-2020
# 1     01-01-2020
# 2     02-01-2020
# 3     01-01-2020
# 4     01-01-2020
# 5     02-01-2020
# 6     01-01-2020
# 7     02-01-2020
# 8     04-01-2020
# 9     03-01-2020
# 10    02-01-2020
# 11    03-01-2020
# 12    01-01-2020
# 13    02-01-2020
# 14    02-01-2020
# 15    02-01-2020
# 16    03-01-2020
# 17    04-01-2020
# 18    02-01-2020
# 19    03-01-2020
# Name: date_reported, dtype: object

# %%
print(df["date_reported"].head(20).tolist())
# Out:
# ['02-01-2020', '01-01-2020', '02-01-2020', '01-01-2020', '01-01-2020', '02-01-2020', '01-01-2020', '02-01-2020', '04-01-2020', '03-01-2020', '02-01-2020', '03-01-2020', '01-01-2020', '02-01-2020', '02-01-2020', '02-01-2020', '03-01-2020', '04-01-2020', '02-01-2020', '03-01-2020']

# %%
df["date_reported"] = pd.to_datetime(
    df["date_reported"],
    format="%d-%m-%Y",
    errors="coerce"
)

# %%
df
# Out:
#        report_number date_reported date_of_occurrence time_of_occurrence  \
# 0                  1    2020-01-02         2020-01-01    01-01-2020 1.11
# 1                  2    2020-01-01         2020-01-01    01-01-2020 6.26
# 2                  3    2020-01-02         2020-01-01   01-01-2020 14.30
# 3                  4    2020-01-01         2020-01-01   01-01-2020 14.46
# 4                  5    2020-01-01         2020-01-01   01-01-2020 16.51
# ...              ...           ...                ...                ...
# 40155          40156    2024-08-01         2024-07-31    31-07-2024 5.05
# 40156          40157    2024-07-31         2024-07-31    31-07-2024 4.14
# 40157          40158    2024-08-02         2024-07-31   31-07-2024 21.33
# 40158          40159    2024-08-01         2024-07-31   31-07-2024 11.05
# 40159          40160    2024-07-31         2024-07-31   31-07-2024 17.19
#
#             city  crime_code   crime_description  victim_age victim_gender  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40160 entries, 0 to 40159
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   report_number       40160 non-null  int64
#  1   date_reported       40160 non-null  datetime64[us]
#  2   date_of_occurrence  40160 non-null  datetime64[us]
#  3   time_of_occurrence  40160 non-null  str
#  4   city                40160 non-null  str
#  5   crime_code          40160 non-null  int64
#  6   crime_description   40160 non-null  str
#  7   victim_age          40160 non-null  int64
#  8   victim_gender       40160 non-null  str
#  9   weapon_used         40160 non-null  str
#  10  crime_domain        40160 non-null  str
#  11  police_deployed     40160 non-null  int64
#  12  case_closed         40160 non-null  str
#  13  date_case_closed    40160 non-null  str
# dtypes: datetime64[us](2), int64(4), str(8)
# memory usage: 6.8 MB

# %%
print(df["time_of_occurrence"].head(10).tolist())
# Out:
# ['01-01-2020 1.11', '01-01-2020 6.26', '01-01-2020 14.30', '01-01-2020 14.46', '01-01-2020 16.51', '01-01-2020 17.09', '01-01-2020 14.08', '02-01-2020 6.33', '02-01-2020 6.34', '01-01-2020 17.50']

# %%
df["time_of_occurrence"] = df["time_of_occurrence"].str.split().str[1]

print(df["time_of_occurrence"].head())
# Out:
# 0     1.11
# 1     6.26
# 2    14.30
# 3    14.46
# 4    16.51
# Name: time_of_occurrence, dtype: object

# %%
df["time_of_occurrence"] = df["time_of_occurrence"].str.replace(".", ":", regex=False)

print(df["time_of_occurrence"].head())
# Out:
# 0     1:11
# 1     6:26
# 2    14:30
# 3    14:46
# 4    16:51
# Name: time_of_occurrence, dtype: object

# %%
df["time_of_occurrence"] = df["time_of_occurrence"].apply(
    lambda x: x if len(x.split(":")[0]) == 2 else "0" + x
)

print(df["time_of_occurrence"].head())
# Out:
# 0    01:11
# 1    06:26
# 2    14:30
# 3    14:46
# 4    16:51
# Name: time_of_occurrence, dtype: str

# %%
df["time_of_occurrence"] = pd.to_datetime(
    df["time_of_occurrence"],
    format="%H:%M",
    errors="coerce"
).dt.time

# %%
df
# Out:
#        report_number date_reported date_of_occurrence time_of_occurrence  \
# 0                  1    2020-01-02         2020-01-01           01:11:00
# 1                  2    2020-01-01         2020-01-01           06:26:00
# 2                  3    2020-01-02         2020-01-01           14:30:00
# 3                  4    2020-01-01         2020-01-01           14:46:00
# 4                  5    2020-01-01         2020-01-01           16:51:00
# ...              ...           ...                ...                ...
# 40155          40156    2024-08-01         2024-07-31           05:05:00
# 40156          40157    2024-07-31         2024-07-31           04:14:00
# 40157          40158    2024-08-02         2024-07-31           21:33:00
# 40158          40159    2024-08-01         2024-07-31           11:05:00
# 40159          40160    2024-07-31         2024-07-31           17:19:00
#
#             city  crime_code   crime_description  victim_age victim_gender  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40160 entries, 0 to 40159
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   report_number       40160 non-null  int64
#  1   date_reported       40160 non-null  datetime64[us]
#  2   date_of_occurrence  40160 non-null  datetime64[us]
#  3   time_of_occurrence  40160 non-null  object
#  4   city                40160 non-null  str
#  5   crime_code          40160 non-null  int64
#  6   crime_description   40160 non-null  str
#  7   victim_age          40160 non-null  int64
#  8   victim_gender       40160 non-null  str
#  9   weapon_used         40160 non-null  str
#  10  crime_domain        40160 non-null  str
#  11  police_deployed     40160 non-null  int64
#  12  case_closed         40160 non-null  str
#  13  date_case_closed    40160 non-null  str
# dtypes: datetime64[us](2), int64(4), object(1), str(7)
# memory usage: 6.2+ MB

# %%
print(df["time_of_occurrence"].head())
print(df["time_of_occurrence"].dtype)
# Out:
# 0    01:11:00
# 1    06:26:00
# 2    14:30:00
# 3    14:46:00
# 4    16:51:00
# Name: time_of_occurrence, dtype: object
# object

# %%
df["crime_hour"] = df["time_of_occurrence"].apply(lambda x: x.hour)

# %%
df
# Out:
#        report_number date_reported date_of_occurrence time_of_occurrence  \
# 0                  1    2020-01-02         2020-01-01           01:11:00
# 1                  2    2020-01-01         2020-01-01           06:26:00
# 2                  3    2020-01-02         2020-01-01           14:30:00
# 3                  4    2020-01-01         2020-01-01           14:46:00
# 4                  5    2020-01-01         2020-01-01           16:51:00
# ...              ...           ...                ...                ...
# 40155          40156    2024-08-01         2024-07-31           05:05:00
# 40156          40157    2024-07-31         2024-07-31           04:14:00
# 40157          40158    2024-08-02         2024-07-31           21:33:00
# 40158          40159    2024-08-01         2024-07-31           11:05:00
# 40159          40160    2024-07-31         2024-07-31           17:19:00
#
#             city  crime_code   crime_description  victim_age victim_gender  \
# ...

# %%
df.drop("crime_hour", axis=1, inplace=True)

# %%
df
# Out:
#        report_number date_reported date_of_occurrence time_of_occurrence  \
# 0                  1    2020-01-02         2020-01-01           01:11:00
# 1                  2    2020-01-01         2020-01-01           06:26:00
# 2                  3    2020-01-02         2020-01-01           14:30:00
# 3                  4    2020-01-01         2020-01-01           14:46:00
# 4                  5    2020-01-01         2020-01-01           16:51:00
# ...              ...           ...                ...                ...
# 40155          40156    2024-08-01         2024-07-31           05:05:00
# 40156          40157    2024-07-31         2024-07-31           04:14:00
# 40157          40158    2024-08-02         2024-07-31           21:33:00
# 40158          40159    2024-08-01         2024-07-31           11:05:00
# 40159          40160    2024-07-31         2024-07-31           17:19:00
#
#             city  crime_code   crime_description  victim_age victim_gender  \
# ...

# %%
print(df["date_case_closed"].head(10).tolist())
# Out:
# ['Null', 'Null', 'Null', '29-04-2020 5.00', '08-01-2020 21.00', '30-03-2020 3.00', '24-03-2020 16.00', 'Null', 'Null', 'Null']

# %%
import pandas as pd

# Replace 'Null' with missing values
df["date_case_closed"] = df["date_case_closed"].replace("Null", pd.NA)

# Extract only the date (works only for non-null values)
df["date_case_closed"] = df["date_case_closed"].str.split().str[0]

# Convert to datetime
df["date_case_closed"] = pd.to_datetime(
    df["date_case_closed"],
    format="%d-%m-%Y",
    errors="coerce"
)

# %%
df
# Out:
#        report_number date_reported date_of_occurrence time_of_occurrence  \
# 0                  1    2020-01-02         2020-01-01           01:11:00
# 1                  2    2020-01-01         2020-01-01           06:26:00
# 2                  3    2020-01-02         2020-01-01           14:30:00
# 3                  4    2020-01-01         2020-01-01           14:46:00
# 4                  5    2020-01-01         2020-01-01           16:51:00
# ...              ...           ...                ...                ...
# 40155          40156    2024-08-01         2024-07-31           05:05:00
# 40156          40157    2024-07-31         2024-07-31           04:14:00
# 40157          40158    2024-08-02         2024-07-31           21:33:00
# 40158          40159    2024-08-01         2024-07-31           11:05:00
# 40159          40160    2024-07-31         2024-07-31           17:19:00
#
#             city  crime_code   crime_description  victim_age victim_gender  \
# ...

# %%
print(df["date_case_closed"].head(10).tolist())
# Out:
# [NaT, NaT, NaT, Timestamp('2020-04-29 00:00:00'), Timestamp('2020-01-08 00:00:00'), Timestamp('2020-03-30 00:00:00'), Timestamp('2020-03-24 00:00:00'), NaT, NaT, NaT]

# %%
df["date_case_closed"] = df["date_case_closed"].astype(object)
df["date_case_closed"] = df["date_case_closed"].fillna("Null")

# %%
df
# Out:
#        report_number date_reported date_of_occurrence time_of_occurrence  \
# 0                  1    2020-01-02         2020-01-01           01:11:00
# 1                  2    2020-01-01         2020-01-01           06:26:00
# 2                  3    2020-01-02         2020-01-01           14:30:00
# 3                  4    2020-01-01         2020-01-01           14:46:00
# 4                  5    2020-01-01         2020-01-01           16:51:00
# ...              ...           ...                ...                ...
# 40155          40156    2024-08-01         2024-07-31           05:05:00
# 40156          40157    2024-07-31         2024-07-31           04:14:00
# 40157          40158    2024-08-02         2024-07-31           21:33:00
# 40158          40159    2024-08-01         2024-07-31           11:05:00
# 40159          40160    2024-07-31         2024-07-31           17:19:00
#
#             city  crime_code   crime_description  victim_age victim_gender  \
# ...

# %%
print(df["date_case_closed"].head(10).tolist())
# Out:
# ['Null', 'Null', 'Null', Timestamp('2020-04-29 00:00:00'), Timestamp('2020-01-08 00:00:00'), Timestamp('2020-03-30 00:00:00'), Timestamp('2020-03-24 00:00:00'), 'Null', 'Null', 'Null']

# %%
print(df["date_case_closed"].head(10).tolist())
# Out:
# ['Null', 'Null', 'Null', Timestamp('2020-04-29 00:00:00'), Timestamp('2020-01-08 00:00:00'), Timestamp('2020-03-30 00:00:00'), Timestamp('2020-03-24 00:00:00'), 'Null', 'Null', 'Null']

# %%
df["date_case_closed"] = df["date_case_closed"].apply(
    lambda x: x.strftime("%d-%m-%Y") if isinstance(x, pd.Timestamp) else "Null"
)

# %%
df
# Out:
#        report_number date_reported date_of_occurrence time_of_occurrence  \
# 0                  1    2020-01-02         2020-01-01           01:11:00
# 1                  2    2020-01-01         2020-01-01           06:26:00
# 2                  3    2020-01-02         2020-01-01           14:30:00
# 3                  4    2020-01-01         2020-01-01           14:46:00
# 4                  5    2020-01-01         2020-01-01           16:51:00
# ...              ...           ...                ...                ...
# 40155          40156    2024-08-01         2024-07-31           05:05:00
# 40156          40157    2024-07-31         2024-07-31           04:14:00
# 40157          40158    2024-08-02         2024-07-31           21:33:00
# 40158          40159    2024-08-01         2024-07-31           11:05:00
# 40159          40160    2024-07-31         2024-07-31           17:19:00
#
#             city  crime_code   crime_description  victim_age victim_gender  \
# ...

# %%
# Create a new column based on time of occurrence
def crime_period(time):
    hour = time.hour

    if 5 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 17:
        return "Afternoon"
    elif 17 <= hour < 21:
        return "Evening"
    else:
        return "Night"

df["crime_occurred"] = df["time_of_occurrence"].apply(crime_period)

# %%
df
# Out:
#        report_number date_reported date_of_occurrence time_of_occurrence  \
# 0                  1    2020-01-02         2020-01-01           01:11:00
# 1                  2    2020-01-01         2020-01-01           06:26:00
# 2                  3    2020-01-02         2020-01-01           14:30:00
# 3                  4    2020-01-01         2020-01-01           14:46:00
# 4                  5    2020-01-01         2020-01-01           16:51:00
# ...              ...           ...                ...                ...
# 40155          40156    2024-08-01         2024-07-31           05:05:00
# 40156          40157    2024-07-31         2024-07-31           04:14:00
# 40157          40158    2024-08-02         2024-07-31           21:33:00
# 40158          40159    2024-08-01         2024-07-31           11:05:00
# 40159          40160    2024-07-31         2024-07-31           17:19:00
#
#             city  crime_code   crime_description  victim_age victim_gender  \
# ...

# %%
# Function to categorize age
def age_group(age):
    if age <= 12:
        return "Child"
    elif age <= 19:
        return "Teenager"
    elif age <= 59:
        return "Adult"
    else:
        return "Senior-Citizen"

# Create new column
df["age_group"] = df["victim_age"].apply(age_group)

# %%
df
# Out:
#        report_number date_reported date_of_occurrence time_of_occurrence  \
# 0                  1    2020-01-02         2020-01-01           01:11:00
# 1                  2    2020-01-01         2020-01-01           06:26:00
# 2                  3    2020-01-02         2020-01-01           14:30:00
# 3                  4    2020-01-01         2020-01-01           14:46:00
# 4                  5    2020-01-01         2020-01-01           16:51:00
# ...              ...           ...                ...                ...
# 40155          40156    2024-08-01         2024-07-31           05:05:00
# 40156          40157    2024-07-31         2024-07-31           04:14:00
# 40157          40158    2024-08-02         2024-07-31           21:33:00
# 40158          40159    2024-08-01         2024-07-31           11:05:00
# 40159          40160    2024-07-31         2024-07-31           17:19:00
#
#             city  crime_code   crime_description  victim_age victim_gender  \
# ...

# %%
df.isnull().sum()
# Out:
# report_number         0
# date_reported         0
# date_of_occurrence    0
# time_of_occurrence    0
# city                  0
# crime_code            0
# crime_description     0
# victim_age            0
# victim_gender         0
# weapon_used           0
# crime_domain          0
# police_deployed       0
# case_closed           0
# date_case_closed      0
# crime_occurred        0
# age_group             0
# dtype: int64

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\Dell\OneDrive\Desktop\Crime_Project\Crime-Analytics-in-India\etl

# %%
df.to_csv("../cleaned_crime_dataset.csv", index=False)
